# %% [markdown]
# # My Jupter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Moe Alaba**
#
# I would like to become a data analyst.

# %% [markdown]
# _I am inteseted in data sciecne because: Love of data manipulation, Love of conclusions based on data._

# %% [markdown]
# This code will show you magic

# %%
print ("Magic")
# Out:
# Magic

# %% [markdown]
# - Love
# - Compassion
# - Honesty
